# %% [markdown]
# Example taken from https://docs.dask.org/en/stable/graphviz.html

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from time import sleep
import numpy as np

from dask4in2p3.dask4in2p3 import Dask4in2p3
import dask

# Creating a Dask4in2p3 object  (with a default Python virtual environment)
dask4in2p3 = Dask4in2p3()

client = dask4in2p3.new_client(dask_worker_jobs=10, 
                               dask_worker_partition='dask',
                               dask_worker_memory=3,
                               dask_worker_time='00:30:00',
                               wait_for_workers_timeout=300
                              )
# Out:
# 12:21:52,434 INFO    Creating and launching the SLURM jobs(s)
# 12:21:52,486 INFO    Waiting for the dask-scheduler SLURM job to be in RUNNING status
# 12:22:02,590 INFO    I've got the dask-scheduler SLURM job in RUNNING status
# 12:22:02,593 INFO    Waiting for the dask-worker SLURM job(s) to be in RUNNING status
# 12:22:17,700 INFO    I've got the expected count (=10) dask-worker SLURM job(s) in RUNNING status
# 12:22:42,046 INFO    A Dask client has been provided

# %%
client
# Out:
# <Client: 'tls://134.158.170.15:65485' processes=7 threads=7, memory=19.53 GiB>

# %%
import dask.array as da
x = da.ones((15, 15), chunks=(5, 5))

y = x + x.T

# y.compute()

# visualize the low level Dask graph
y.visualize(filename='transpose.svg', optimize_graph=True)

# %%
y.compute()
# Out:
# array([[2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.],
#        [2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.]])

# %%
y.dask.visualize(filename='transpose-hlg.svg')
# Out:
# 2022-11-21 14:23:34,207 - distributed.client - ERROR - Failed to reconnect to scheduler after 90.00 seconds, closing client
